# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import NearestNeighbors
import pickle
import os
import ast
import pandas as pd

# Display settings
pd.set_option('display.max_columns', None)
sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = (12, 6)

print("✅ Libraries imported successfully!")
# Out:
# ✅ Libraries imported successfully!

# %%
#Load dataset
movies=pd.read_csv('data/tmdb_5000_movies.csv')
credits=pd.read_csv('data/tmdb_5000_credits.csv')
print(f"Movies shape:{movies.shape}")
print(f"Credits shape:{credits.shape}")
# Out:
# Movies shape:(4803, 20)
# Credits shape:(4803, 4)

# %%
#Merge dataset
movies=movies.merge(credits,on='title',how='left')
print(f"merged dataset:{movies.shape}")
print(f"\nColumns:{movies.columns.tolist()}")
# Out:
# merged dataset:(4821, 26)
#
# Columns:['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language', 'original_title', 'overview', 'popularity', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'vote_average', 'vote_count', 'movie_id_x', 'cast_x', 'crew_x', 'movie_id_y', 'cast_y', 'crew_y']

# %%
#Dataset Overview
print(" Dataset Overview:")
print(f"Total Movies: {len(movies):,}")
print(f"Date Range: {movies['release_date'].min()} to {movies['release_date'].max()}")
print(f"Average Rating: {movies['vote_average'].mean():.1f}/10")
print(f"Average Budget: ${movies['budget'].mean():,.0f}")
print(f"Average Revenue: ${movies['revenue'].mean():,.0f}")

# Top rated movies
print("\n Top 10 Rated Movies:")
top_rated = movies.nlargest(10, 'vote_average')[['title', 'vote_average', 'popularity']]
display(top_rated)
# Out:
#  Dataset Overview:
# Total Movies: 4,821
# Date Range: 1916-09-04 to 2017-02-03
# Average Rating: 6.1/10
# Average Budget: $28,993,458
# Average Revenue: $82,303,950
#
#  Top 10 Rated Movies:
#                          title  vote_average  popularity
# 3528          Stiff Upper Lips          10.0    0.356495
# 4060     Dancer, Texas Pop. 81          10.0    0.376662
# 4262     Me You and Five Bucks          10.0    0.094105
# 4680            Little Big Top          10.0    0.092100
# 4007                 Sardaarji           9.5    0.296981
# 2392            One Man's Hero           9.3    0.910529
# 1887  The Shawshank Redemption           8.5  136.747729
# 2979        There Goes My Baby           8.5    0.037073
# 2802     The Prisoner of Zenda           8.4    4.021389
# 3346             The Godfather           8.4  143.659698
